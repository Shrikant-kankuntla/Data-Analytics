# %%
import pandas as pd

df = pd.read_csv("customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 3895            4.2                  No  2-Day Shipping               No
# 3896            4.5                  No    Store Pickup               No
# 3897            2.9                  No        Standard               No
# 3898            3.8                  No         Express               No
# 3899            3.1                  No    Store Pickup               No
#
#      Promo Code Used  Previous Purchases Payment Method Frequency of Purchases
# 3895              No                  32          Venmo                 Weekly
# 3896              No                  41  Bank Transfer              Bi-Weekly
# 3897              No                  24          Venmo              Quarterly
# 3898              No                  24          Venmo                 Weekly
# 3899              No                  33          Venmo              Quarterly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB

# %%
df.describe(include="all")
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# unique                    NaN       50     4     25       4            NaN
# top                       NaN  Montana     M  Olive  Spring            NaN
# freq                      NaN       96  1755    177     999            NaN
# mean                59.764359      NaN   NaN    NaN     NaN       3.750065
# std                 23.685392      NaN   NaN    NaN     NaN       0.716983
# min                 20.000000      NaN   NaN    NaN     NaN       2.500000
# 25%                 39.000000      NaN   NaN    NaN     NaN       3.100000
# 50%                 60.000000      NaN   NaN    NaN     NaN       3.800000
# 75%                 81.000000      NaN   NaN    NaN     NaN       4.400000
# max                100.000000      NaN   NaN    NaN     NaN       5.000000
#
#        Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# count                 3900           3900             3900            3900
# unique                   2              6                2               2
# top                     No  Free Shipping               No              No
# freq                  2847            675             2223            2223
# mean                   NaN            NaN              NaN             NaN
# std                    NaN            NaN              NaN             NaN
# min                    NaN            NaN              NaN             NaN
# 25%                    NaN            NaN              NaN             NaN
# 50%                    NaN            NaN              NaN             NaN
# 75%                    NaN            NaN              NaN             NaN
# max                    NaN            NaN              NaN             NaN
#
#         Previous Purchases Payment Method Frequency of Purchases
# count          3900.000000           3900                   3900
# unique                 NaN              6                      7
# top                    NaN         PayPal         Every 3 Months
# freq                   NaN            677                    584
# mean             25.351538            NaN                    NaN
# std              14.447125            NaN                    NaN
# min               1.000000            NaN                    NaN
# 25%              13.000000            NaN                    NaN
# 50%              25.000000            NaN                    NaN
# 75%              38.000000            NaN                    NaN
# max              50.000000            NaN                    NaN

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df = df.rename(columns = {'purchase_amount_(usd)': 'purchase_amount'})

# %%
df.isnull().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# item_purchased            0
# category                  0
# purchase_amount           0
# location                  0
# size                      0
# color                     0
# season                    0
# review_rating             0
# subscription_status       0
# shipping_type             0
# discount_applied          0
# promo_code_used           0
# previous_purchases        0
# payment_method            0
# frequency_of_purchases    0
# dtype: int64

# %%
labels = ['Young','Adult','Middle','Senior']
df['age_group'] = pd.qcut(df['age'],q=4,labels=labels)

# %%
df.head(30)
# Out:
#     customer_id  age gender item_purchased     category  purchase_amount  \
# 0             1   55   Male         Blouse     Clothing               53
# 1             2   19   Male        Sweater     Clothing               64
# 2             3   50   Male          Jeans     Clothing               73
# 3             4   21   Male        Sandals     Footwear               90
# 4             5   45   Male         Blouse     Clothing               49
# 5             6   46   Male       Sneakers     Footwear               20
# 6             7   63   Male          Shirt     Clothing               85
# 7             8   27   Male         Shorts     Clothing               34
# 8             9   26   Male           Coat    Outerwear               97
# 9            10   57   Male        Handbag  Accessories               31
# 10           11   53   Male          Shoes     Footwear               34
# 11           12   30   Male         Shorts     Clothing               68
# 12           13   61   Male           Coat    Outerwear               72
# 13           14   65   Male          Dress     Clothing               51
# 14           15   64   Male           Coat    Outerwear               53
# 15           16   64   Male          Skirt     Clothing               81
# 16           17   25   Male     Sunglasses  Accessories               36
# 17           18   53   Male          Dress     Clothing               38
# 18           19   52   Male        Sweater     Clothing               48
# 19           20   66   Male          Pants     Clothing               90
# 20           21   21   Male          Pants     Clothing               51
# 21           22   31   Male          Pants     Clothing               62
# 22           23   56   Male          Pants     Clothing               37
# 23           24   31   Male          Pants     Clothing               88
# 24           25   18   Male         Jacket    Outerwear               22
# 25           26   18   Male         Hoodie     Clothing               25
# 26           27   38   Male        Jewelry  Accessories               20
# 27           28   56   Male         Shorts     Clothing               56
# 28           29   54   Male        Handbag  Accessories               94
# 29           30   31   Male          Dress     Clothing               48
#
#           location size      color  season  review_rating subscription_status  \
# 0         Kentucky    L       Gray  Winter            3.1                 Yes
# 1            Maine    L     Maroon  Winter            3.1                 Yes
# 2    Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3     Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4           Oregon    M  Turquoise  Spring            2.7                 Yes
# 5          Wyoming    M      White  Summer            2.9                 Yes
# 6          Montana    M       Gray    Fall            3.2                 Yes
# 7        Louisiana    L   Charcoal  Winter            3.2                 Yes
# 8    West Virginia    L     Silver  Summer            2.6                 Yes
# 9         Missouri    M       Pink  Spring            4.8                 Yes
# 10        Arkansas    L     Purple    Fall            4.1                 Yes
# 11          Hawaii    S      Olive  Winter            4.9                 Yes
# 12        Delaware    M       Gold  Winter            4.5                 Yes
# 13   New Hampshire    M     Violet  Spring            4.7                 Yes
# 14        New York    L       Teal  Winter            4.7                 Yes
# 15    Rhode Island    M       Teal  Winter            2.8                 Yes
# 16         Alabama    S       Gray  Spring            4.1                 Yes
# 17     Mississippi   XL   Lavender  Winter            4.7                 Yes
# 18         Montana    S      Black  Summer            4.6                 Yes
# 19    Rhode Island    M      Green  Summer            3.3                 Yes
# 20       Louisiana    M      Black  Winter            2.8                 Yes
# 21  North Carolina    M   Charcoal  Winter            4.1                 Yes
# 22      California    M      Peach  Summer            3.2                 Yes
# 23        Oklahoma   XL      White  Winter            4.4                 Yes
# 24         Florida    M      Green    Fall            2.9                 Yes
# 25           Texas    M     Silver  Summer            3.6                 Yes
# 26          Nevada    M        Red  Spring            3.6                 Yes
# 27        Kentucky    L       Cyan  Summer            5.0                 Yes
# 28  North Carolina    M       Gray    Fall            4.4                 Yes
# 29         Wyoming    S      Black    Fall            4.1                 Yes
#
#      shipping_type discount_applied promo_code_used  previous_purchases  \
# 0          Express              Yes             Yes                  14
# 1          Express              Yes             Yes                   2
# 2    Free Shipping              Yes             Yes                  23
# 3     Next Day Air              Yes             Yes                  49
# 4    Free Shipping              Yes             Yes                  31
# 5         Standard              Yes             Yes                  14
# 6    Free Shipping              Yes             Yes                  49
# 7    Free Shipping              Yes             Yes                  19
# 8          Express              Yes             Yes                   8
# 9   2-Day Shipping              Yes             Yes                   4
# 10    Store Pickup              Yes             Yes                  26
# 11    Store Pickup              Yes             Yes                  10
# 12         Express              Yes             Yes                  37
# 13         Express              Yes             Yes                  31
# 14   Free Shipping              Yes             Yes                  34
# 15    Store Pickup              Yes             Yes                   8
# 16    Next Day Air              Yes             Yes                  44
# 17  2-Day Shipping              Yes             Yes                  36
# 18   Free Shipping              Yes             Yes                  17
# 19        Standard              Yes             Yes                  46
# 20         Express              Yes             Yes                  50
# 21    Store Pickup              Yes             Yes                  22
# 22    Store Pickup              Yes             Yes                  32
# 23         Express              Yes             Yes                  40
# 24    Store Pickup              Yes             Yes                  16
# 25         Express              Yes             Yes                  14
# 26    Next Day Air              Yes             Yes                  13
# 27    Next Day Air              Yes             Yes                   7
# 28   Free Shipping              Yes             Yes                  41
# 29    Store Pickup              Yes             Yes                  14
#
#    payment_method frequency_of_purchases age_group
# 0           Venmo            Fortnightly    Middle
# 1            Cash            Fortnightly     Young
# 2     Credit Card                 Weekly    Middle
# 3          PayPal                 Weekly     Young
# 4          PayPal               Annually    Middle
# 5           Venmo                 Weekly    Middle
# 6            Cash              Quarterly    Senior
# 7     Credit Card                 Weekly     Young
# 8           Venmo               Annually     Young
# 9            Cash              Quarterly    Middle
# 10  Bank Transfer              Bi-Weekly    Middle
# 11  Bank Transfer            Fortnightly     Young
# 12          Venmo            Fortnightly    Senior
# 13         PayPal                 Weekly    Senior
# 14     Debit Card                 Weekly    Senior
# 15         PayPal                Monthly    Senior
# 16     Debit Card              Bi-Weekly     Young
# 17          Venmo              Quarterly    Middle
# 18           Cash                 Weekly    Middle
# 19     Debit Card              Bi-Weekly    Senior
# 20           Cash         Every 3 Months     Young
# 21     Debit Card              Quarterly     Young
# 22     Debit Card               Annually    Middle
# 23    Credit Card                 Weekly     Young
# 24     Debit Card                 Weekly     Young
# 25         PayPal               Annually     Young
# 26    Credit Card               Annually     Adult
# 27  Bank Transfer         Every 3 Months    Middle
# 28         PayPal         Every 3 Months    Middle
# 29    Credit Card                 Weekly     Young

# %%
frequency_mapping ={
'Fortnightly':1,
'Weekly':7,
'Quarterly':90,
'Annually':365,
'Monthly':30,	
'Every 3 Months':90,
'Bi-Weekly':14,
}
df['purchase_frequency_days']= df['frequency_of_purchases'].map(frequency_mapping)

# %%
df = df.drop('promo_code_used', axis =1)

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp314-cp314-win_amd64.whl.metadata (5.1 kB)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.44-py3-none-any.whl.metadata (9.5 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.2.4-cp314-cp314-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\shrik\appdata\local\programs\python\python314\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading psycopg2_binary-2.9.11-cp314-cp314-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 3.1 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.8 MB 3.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 3.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 3.2 MB/s  0:00:00
# Downloading sqlalchemy-2.0.44-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/1.9 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 5.2 MB/s  0:00:00
# Downloading greenlet-3.2.4-cp314-cp314-win_amd64.whl (303 kB)
# Installing collected packages: psycopg2-binary, greenlet, sqlalchemy
#
#    ---------------------------------------- 0/3 [psycopg2-binary]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    ---------------------------------------- 3/3 [sqlalchemy]
#
# Successfully installed greenlet-3.2.4 psycopg2-binary-2.9.11 sqlalchemy-2.0.44
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

username="postgres"
password="2802"
host="localhost"
port="5432"
database="customer_behaviour"

engine= create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

table_name="customer"
df.to_sql(table_name,engine,if_exists="replace",index=False)
print(f"database successfully uploaded in '{table_name}''{database}'")
# Out:
# database successfully uploaded in 'customer''customer_behaviour'
